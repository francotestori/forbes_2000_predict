# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import RandomizedSearchCV

import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 671993

# %%
df = pd.read_csv('../data/forbes_2000_iqr_range_feature_engineering.csv')

# %%
def train_test_split_by_year(x_df: pd.DataFrame, y_df: pd.DataFrame):
    X_train = x_df[x_df.test == False].drop('test', axis=1).to_numpy()
    X_test = x_df[x_df.test].drop('test', axis=1).to_numpy()
    y_train = y_df[x_df.test == False].drop('test', axis=1).to_numpy().flatten()
    y_test = y_df[x_df.test].drop('test', axis=1).to_numpy().flatten()

    return X_train, X_test, y_train, y_test

# %%
x=df.drop(['company','market_value','year','industry','sector','country','continent'], axis=1)
y=df.loc[:,['market_value','test']]

X_train, X_test, y_train, y_test = train_test_split_by_year(x, y)

# %%
params = {
    'max_depth': [3, 5, 6, 10, 15, 20],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.2, 0.3],
    'subsample': np.arange(0.5, 1.0, 0.1),
    'colsample_bytree': np.arange(0.4, 1.0, 0.1),
    'colsample_bylevel': np.arange(0.4, 1.0, 0.1),
    'n_estimators': [100, 500, 1000],
    'reg_alpha':[0, 1, 10, 50, 100],
    'reg_lambda': [1, 10, 50, 100]
}


# Instantiate an XGBoost object with hyperparameters
xgb_reg = xgb.XGBRegressor(
    n_jobs=2,
    objective='reg:squarederror',
    booster='gbtree',
    random_state=RANDOM_SEED
)

# %%
clf = RandomizedSearchCV(
    estimator=xgb_reg,
    param_distributions=params,
    scoring='neg_mean_squared_error',
    n_iter=25,
    verbose=1250
)

clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5; 1/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5
# [CV 1/5; 1/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5;, score=-63.562 total time= 1.2min
# [CV 2/5; 1/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5
# [CV 2/5; 1/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5;, score=-26.156 total time= 1.3min
# [CV 3/5; 1/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5
# [CV 3/5; 1/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5;, score=-16.466 total time= 1.4min
# [CV 4/5; 1/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5
# [CV 4/5; 1/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5;, score=-15.273 total time= 1.4min
# [CV 5/5; 1/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5
# [CV 5/5; 1/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.01, max_depth=15, n_estimators=1000, reg_alpha=0, reg_lambda=50, subsample=0.5;, score=-27.302 total time= 1.2min
# [CV 1/5; 2/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999
# [CV 1/5; 2/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999;, score=-90.110 total time=  53.3s
# [CV 2/5; 2/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999
# [CV 2/5; 2/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999;, score=-27.003 total time=  53.4s
# [CV 3/5; 2/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999
# [CV 3/5; 2/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999;, score=-11.576 total time=  53.7s
# [CV 4/5; 2/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999
# [CV 4/5; 2/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999;, score=-11.474 total time=  54.2s
# [CV 5/5; 2/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999
# [CV 5/5; 2/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=20, n_estimators=500, reg_alpha=10, reg_lambda=10, subsample=0.8999999999999999;, score=-24.164 total time=  53.1s
# [CV 1/5; 3/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7
# [CV 1/5; 3/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7;, score=-85.917 total time=  32.5s
# [CV 2/5; 3/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7
# [CV 2/5; 3/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7;, score=-26.503 total time=  32.1s
# [CV 3/5; 3/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7
# [CV 3/5; 3/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7;, score=-12.740 total time=  32.0s
# [CV 4/5; 3/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7
# [CV 4/5; 3/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7;, score=-12.631 total time=  32.5s
# [CV 5/5; 3/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7
# [CV 5/5; 3/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=500, reg_alpha=100, reg_lambda=1, subsample=0.7;, score=-23.564 total time=  31.7s
# [CV 1/5; 4/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999
# [CV 1/5; 4/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999;, score=-65.045 total time=   3.0s
# [CV 2/5; 4/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999
# [CV 2/5; 4/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999;, score=-28.966 total time=   3.1s
# [CV 3/5; 4/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999
# [CV 3/5; 4/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999;, score=-19.950 total time=   3.0s
# [CV 4/5; 4/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999
# [CV 4/5; 4/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999;, score=-18.337 total time=   3.0s
# [CV 5/5; 4/25] START colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999
# [CV 5/5; 4/25] END colsample_bylevel=0.6, colsample_bytree=0.8999999999999999, learning_rate=0.05, max_depth=6, n_estimators=100, reg_alpha=10, reg_lambda=50, subsample=0.8999999999999999;, score=-34.717 total time=   3.1s
# [CV 1/5; 5/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5
# [CV 1/5; 5/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5;, score=-61.072 total time=   6.2s
# [CV 2/5; 5/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5
# [CV 2/5; 5/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5;, score=-25.745 total time=   6.3s
# [CV 3/5; 5/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5
# [CV 3/5; 5/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5;, score=-22.139 total time=   6.9s
# [CV 4/5; 5/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5
# [CV 4/5; 5/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5;, score=-20.084 total time=   6.5s
# [CV 5/5; 5/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5
# [CV 5/5; 5/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=100, subsample=0.5;, score=-32.403 total time=   6.5s
# [CV 1/5; 6/25] START colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999
# [CV 1/5; 6/25] END colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999;, score=-73.335 total time=  44.0s
# [CV 2/5; 6/25] START colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999
# [CV 2/5; 6/25] END colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999;, score=-26.953 total time=  42.2s
# [CV 3/5; 6/25] START colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999
# [CV 3/5; 6/25] END colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999;, score=-14.555 total time=  44.4s
# [CV 4/5; 6/25] START colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999
# [CV 4/5; 6/25] END colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999;, score=-13.372 total time=  46.0s
# [CV 5/5; 6/25] START colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999
# [CV 5/5; 6/25] END colsample_bylevel=0.6, colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.8999999999999999;, score=-26.227 total time=  45.6s
# [CV 1/5; 7/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6
# [CV 1/5; 7/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6;, score=-48.240 total time=  10.3s
# [CV 2/5; 7/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6
# [CV 2/5; 7/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6;, score=-33.364 total time=   9.2s
# [CV 3/5; 7/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6
# [CV 3/5; 7/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6;, score=-26.857 total time=   9.3s
# [CV 4/5; 7/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6
# [CV 4/5; 7/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6;, score=-26.399 total time=   9.7s
# [CV 5/5; 7/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6
# [CV 5/5; 7/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=50, reg_lambda=100, subsample=0.6;, score=-42.041 total time=   8.9s
# [CV 1/5; 8/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 1/5; 8/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-88.125 total time=  20.7s
# [CV 2/5; 8/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 2/5; 8/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-33.693 total time=  19.2s
# [CV 3/5; 8/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 3/5; 8/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-14.896 total time=  19.1s
# [CV 4/5; 8/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 4/5; 8/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-14.562 total time=  19.1s
# [CV 5/5; 8/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 5/5; 8/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=3, n_estimators=1000, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-26.072 total time=  19.0s
# [CV 1/5; 9/25] START colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 1/5; 9/25] END colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-51.841 total time=   3.3s
# [CV 2/5; 9/25] START colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 2/5; 9/25] END colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-29.558 total time=   3.3s
# [CV 3/5; 9/25] START colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 3/5; 9/25] END colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-25.631 total time=   3.3s
# [CV 4/5; 9/25] START colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 4/5; 9/25] END colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-23.096 total time=   3.3s
# [CV 5/5; 9/25] START colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 5/5; 9/25] END colsample_bylevel=0.7, colsample_bytree=0.4, learning_rate=0.05, max_depth=10, n_estimators=100, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-34.398 total time=   3.3s
# [CV 1/5; 10/25] START colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 1/5; 10/25] END colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-72.413 total time=  10.5s
# [CV 2/5; 10/25] START colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 2/5; 10/25] END colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-28.023 total time=  10.5s
# [CV 3/5; 10/25] START colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 3/5; 10/25] END colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-16.482 total time=  10.6s
# [CV 4/5; 10/25] START colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 4/5; 10/25] END colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-14.809 total time=  10.5s
# [CV 5/5; 10/25] START colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5
# [CV 5/5; 10/25] END colsample_bylevel=0.4, colsample_bytree=0.7999999999999999, learning_rate=0.03, max_depth=6, n_estimators=500, reg_alpha=10, reg_lambda=100, subsample=0.5;, score=-26.297 total time=  10.5s
# [CV 1/5; 11/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 1/5; 11/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-67.653 total time=  26.4s
# [CV 2/5; 11/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 2/5; 11/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-26.408 total time=  26.6s
# [CV 3/5; 11/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 3/5; 11/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-17.643 total time=  26.6s
# [CV 4/5; 11/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 4/5; 11/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-15.719 total time=  26.2s
# [CV 5/5; 11/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 5/5; 11/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.01, max_depth=10, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-26.119 total time=  26.2s
# [CV 1/5; 12/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 1/5; 12/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-78.847 total time= 1.4min
# [CV 2/5; 12/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 2/5; 12/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-25.175 total time= 1.4min
# [CV 3/5; 12/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 3/5; 12/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-13.114 total time= 1.4min
# [CV 4/5; 12/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 4/5; 12/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-12.209 total time= 1.4min
# [CV 5/5; 12/25] START colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 5/5; 12/25] END colsample_bylevel=0.8999999999999999, colsample_bytree=0.5, learning_rate=0.03, max_depth=15, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-23.048 total time= 1.3min
# [CV 1/5; 13/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999
# [CV 1/5; 13/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999;, score=-53.234 total time=   8.9s
# [CV 2/5; 13/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999
# [CV 2/5; 13/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999;, score=-34.103 total time=   9.0s
# [CV 3/5; 13/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999
# [CV 3/5; 13/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999;, score=-21.434 total time=   8.9s
# [CV 4/5; 13/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999
# [CV 4/5; 13/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999;, score=-22.233 total time=   8.8s
# [CV 5/5; 13/25] START colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999
# [CV 5/5; 13/25] END colsample_bylevel=0.7, colsample_bytree=0.8999999999999999, learning_rate=0.03, max_depth=15, n_estimators=100, reg_alpha=100, reg_lambda=10, subsample=0.7999999999999999;, score=-37.111 total time=   8.8s
# [CV 1/5; 14/25] START colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 1/5; 14/25] END colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-71.106 total time=  29.6s
# [CV 2/5; 14/25] START colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 2/5; 14/25] END colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-25.525 total time=  29.7s
# [CV 3/5; 14/25] START colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 3/5; 14/25] END colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-13.879 total time=  29.7s
# [CV 4/5; 14/25] START colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 4/5; 14/25] END colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-13.176 total time=  29.7s
# [CV 5/5; 14/25] START colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 5/5; 14/25] END colsample_bylevel=0.7, colsample_bytree=0.6, learning_rate=0.03, max_depth=15, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-25.371 total time=  31.1s
# [CV 1/5; 15/25] START colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999
# [CV 1/5; 15/25] END colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999;, score=-119.402 total time=  19.6s
# [CV 2/5; 15/25] START colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999
# [CV 2/5; 15/25] END colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999;, score=-29.892 total time=  19.8s
# [CV 3/5; 15/25] START colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999
# [CV 3/5; 15/25] END colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999;, score=-9.434 total time=  19.4s
# [CV 4/5; 15/25] START colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999
# [CV 4/5; 15/25] END colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999;, score=-9.454 total time=  19.2s
# [CV 5/5; 15/25] START colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999
# [CV 5/5; 15/25] END colsample_bylevel=0.5, colsample_bytree=0.7999999999999999, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.8999999999999999;, score=-16.154 total time=  19.2s
# [CV 1/5; 16/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5
# [CV 1/5; 16/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5;, score=-46.932 total time=   2.1s
# [CV 2/5; 16/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5
# [CV 2/5; 16/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5;, score=-42.027 total time=   2.2s
# [CV 3/5; 16/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5
# [CV 3/5; 16/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5;, score=-37.225 total time=   2.2s
# [CV 4/5; 16/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5
# [CV 4/5; 16/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5;, score=-34.527 total time=   2.2s
# [CV 5/5; 16/25] START colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5
# [CV 5/5; 16/25] END colsample_bylevel=0.7999999999999999, colsample_bytree=0.4, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=100, reg_lambda=100, subsample=0.5;, score=-51.508 total time=   2.2s
# [CV 1/5; 17/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7
# [CV 1/5; 17/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7;, score=-82.997 total time=   7.3s
# [CV 2/5; 17/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7
# [CV 2/5; 17/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7;, score=-25.862 total time=   7.3s
# [CV 3/5; 17/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7
# [CV 3/5; 17/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7;, score=-16.536 total time=   7.3s
# [CV 4/5; 17/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7
# [CV 4/5; 17/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7;, score=-16.700 total time=   7.3s
# [CV 5/5; 17/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7
# [CV 5/5; 17/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=500, reg_alpha=0, reg_lambda=10, subsample=0.7;, score=-21.548 total time=   7.3s
# [CV 1/5; 18/25] START colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7
# [CV 1/5; 18/25] END colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7;, score=-94.001 total time=   4.9s
# [CV 2/5; 18/25] START colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7
# [CV 2/5; 18/25] END colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7;, score=-28.489 total time=   5.0s
# [CV 3/5; 18/25] START colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7
# [CV 3/5; 18/25] END colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7;, score=-12.421 total time=   4.9s
# [CV 4/5; 18/25] START colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7
# [CV 4/5; 18/25] END colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7;, score=-12.357 total time=   4.9s
# [CV 5/5; 18/25] START colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7
# [CV 5/5; 18/25] END colsample_bylevel=0.6, colsample_bytree=0.7999999999999999, learning_rate=0.2, max_depth=10, n_estimators=100, reg_alpha=50, reg_lambda=50, subsample=0.7;, score=-22.794 total time=   4.9s
# [CV 1/5; 19/25] START colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5
# [CV 1/5; 19/25] END colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5;, score=-96.460 total time=  47.4s
# [CV 2/5; 19/25] START colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5
# [CV 2/5; 19/25] END colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5;, score=-29.622 total time=  47.3s
# [CV 3/5; 19/25] START colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5
# [CV 3/5; 19/25] END colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5;, score=-11.012 total time=  47.7s
# [CV 4/5; 19/25] START colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5
# [CV 4/5; 19/25] END colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5;, score=-10.263 total time=  47.6s
# [CV 5/5; 19/25] START colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5
# [CV 5/5; 19/25] END colsample_bylevel=0.4, colsample_bytree=0.7, learning_rate=0.05, max_depth=15, n_estimators=1000, reg_alpha=10, reg_lambda=50, subsample=0.5;, score=-22.523 total time=  47.2s
# [CV 1/5; 20/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 1/5; 20/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-76.884 total time=   4.0s
# [CV 2/5; 20/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 2/5; 20/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-25.221 total time=   4.0s
# [CV 3/5; 20/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 3/5; 20/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-17.486 total time=   4.0s
# [CV 4/5; 20/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 4/5; 20/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-27.749 total time=   4.1s
# [CV 5/5; 20/25] START colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 5/5; 20/25] END colsample_bylevel=0.4, colsample_bytree=0.5, learning_rate=0.3, max_depth=20, n_estimators=100, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-26.804 total time=   4.1s
# [CV 1/5; 21/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6
# [CV 1/5; 21/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6;, score=-110.773 total time=  38.8s
# [CV 2/5; 21/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6
# [CV 2/5; 21/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6;, score=-28.676 total time=  38.8s
# [CV 3/5; 21/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6
# [CV 3/5; 21/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6;, score=-10.645 total time=  38.6s
# [CV 4/5; 21/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6
# [CV 4/5; 21/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6;, score=-13.240 total time=  38.8s
# [CV 5/5; 21/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6
# [CV 5/5; 21/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.2, max_depth=15, n_estimators=1000, reg_alpha=50, reg_lambda=50, subsample=0.6;, score=-18.945 total time=  38.6s
# [CV 1/5; 22/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 1/5; 22/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-52.975 total time=   8.4s
# [CV 2/5; 22/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 2/5; 22/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-32.351 total time=   8.4s
# [CV 3/5; 22/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 3/5; 22/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-28.307 total time=   8.5s
# [CV 4/5; 22/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 4/5; 22/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-25.742 total time=   8.6s
# [CV 5/5; 22/25] START colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5
# [CV 5/5; 22/25] END colsample_bylevel=0.6, colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500, reg_alpha=50, reg_lambda=50, subsample=0.5;, score=-41.940 total time=   8.5s
# [CV 1/5; 23/25] START colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 1/5; 23/25] END colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-117.376 total time=  11.6s
# [CV 2/5; 23/25] START colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 2/5; 23/25] END colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-32.219 total time=  11.6s
# [CV 3/5; 23/25] START colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 3/5; 23/25] END colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-11.230 total time=  11.5s
# [CV 4/5; 23/25] START colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 4/5; 23/25] END colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-11.948 total time=  11.7s
# [CV 5/5; 23/25] START colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999
# [CV 5/5; 23/25] END colsample_bylevel=0.7, colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000, reg_alpha=100, reg_lambda=1, subsample=0.8999999999999999;, score=-20.019 total time=  11.4s
# [CV 1/5; 24/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 1/5; 24/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-99.971 total time=  14.4s
# [CV 2/5; 24/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 2/5; 24/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-27.594 total time=  14.4s
# [CV 3/5; 24/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 3/5; 24/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-12.836 total time=  14.7s
# [CV 4/5; 24/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 4/5; 24/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-11.874 total time=  15.5s
# [CV 5/5; 24/25] START colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999
# [CV 5/5; 24/25] END colsample_bylevel=0.5, colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1000, reg_alpha=1, reg_lambda=50, subsample=0.7999999999999999;, score=-20.208 total time=  14.8s
# [CV 1/5; 25/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6
# [CV 1/5; 25/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6;, score=-129.417 total time=  14.4s
# [CV 2/5; 25/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6
# [CV 2/5; 25/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6;, score=-42.131 total time=  16.1s
# [CV 3/5; 25/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6
# [CV 3/5; 25/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6;, score=-16.200 total time=  15.4s
# [CV 4/5; 25/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6
# [CV 4/5; 25/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6;, score=-58.586 total time=  14.1s
# [CV 5/5; 25/25] START colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6
# [CV 5/5; 25/25] END colsample_bylevel=0.4, colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1000, reg_alpha=0, reg_lambda=1, subsample=0.6;, score=-59.376 total time=  14.1s
# RandomizedSearchCV(estimator=XGBRegressor(base_score=None, booster='gbtree',
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n_...
#                    param_distributions={'colsample_bylevel': array([0.4, 0.5, 0.6, 0.7, 0.8, 0.9]),
#                                         'colsample_bytree': array([0.4, 0.5, 0.6, 0.7, 0.8, 0.9]),
#                                         'learning_rate': [0.01, 0.03, 0.05, 0.1,
#                                                           0.2, 0.3],
#                                         'max_depth': [3, 5, 6, 10, 15, 20],
#                                         'n_estimators': [100, 500, 1000],
#                                         'reg_alpha': [0, 1, 10, 50, 100],
#                                         'reg_lambda': [1, 10, 50, 100],
#                                         'subsample': array([0.5, 0.6, 0.7, 0.8, 0.9])},
#                    scoring='neg_mean_squared_error', verbose=1250)

# %%
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))
# Out:
# Best parameters: {'subsample': 0.5, 'reg_lambda': 50, 'reg_alpha': 0, 'n_estimators': 1000, 'max_depth': 15, 'learning_rate': 0.01, 'colsample_bytree': 0.5, 'colsample_bylevel': 0.8999999999999999}
# Lowest RMSE:  5.454528827536231
